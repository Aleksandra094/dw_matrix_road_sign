# %%
! pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.38.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
import pandas as pd
import numpy as np

import os
import datetime

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
from skimage import color, exposure
from sklearn.metrics import accuracy_score

from hyperopt import hp, STATUS_OK, tpe, Trials, fmin

# %%
cd 'drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_sign'
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_sign

# %%
train = pd.read_pickle('data/train.p')
test = pd.read_pickle('data/test.p')

X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# %%
if y_train.ndim ==1: y_train=to_categorical(y_train)
if y_test.ndim ==1: y_test=to_categorical(y_test)

input_shape = X_train.shape[1:]
num_classes = y_train.shape[1]

# %%
def train_model(model, X_train, y_train, params_fit={}):
    model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    
    logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H-%M-%S"))
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
    
    model.fit(
        X_train,
        y_train,
        batch_size = params_fit.get('batch_size', 128),
        epochs = params_fit.get('epochs',5),
        verbose = params_fit.get('verbose',1),
        validation_data = params_fit.get('validation_data',(X_train, y_train)),
        callbacks = [tensorboard_callback]
      )
    return model

def predict(model_trained, X_test, y_test, scoring=accuracy_score):

  y_test_norm = np.argmax(y_test, axis=1)
  y_pred_prob = model_trained.predict(X_test)
  y_pred = np.argmax(y_pred_prob, axis=1)

  return scoring(y_test_norm, y_pred)

# %%
def get_cnn_v5(input_shape, num_classes):
  return Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
    Conv2D(filters=32, kernel_size=(3,3), activation='relu',padding='same'),
    MaxPool2D(),
    Dropout(0.3),

    Conv2D(filters=64, kernel_size=(3,3), activation='relu',padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(0.3),

    Conv2D(filters=64, kernel_size=(3,3), activation='relu',padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(0.3),
    Flatten(),

    Dense(1024, activation='relu'),
    Dropout(0.3),

    Dense(1024, activation='relu'),
    Dropout(0.3),

    Dense(num_classes, activation='softmax'),
  ])

# %%
model = get_cnn_v5(input_shape, num_classes)
model_trained = train_model(model, X_train, y_train, params_fit={})
predict(model_trained, X_test, y_test)
# Out:
# Epoch 1/5
# 272/272 [==============================] - 6s 24ms/step - loss: 2.6579 - accuracy: 0.2781 - val_loss: 1.1623 - val_accuracy: 0.6422
# Epoch 2/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.9253 - accuracy: 0.7025 - val_loss: 0.3474 - val_accuracy: 0.8764
# Epoch 3/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.4577 - accuracy: 0.8564 - val_loss: 0.1175 - val_accuracy: 0.9629
# Epoch 4/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.2991 - accuracy: 0.9085 - val_loss: 0.0731 - val_accuracy: 0.9816
# Epoch 5/5
# 272/272 [==============================] - 6s 22ms/step - loss: 0.2264 - accuracy: 0.9314 - val_loss: 0.0482 - val_accuracy: 0.9850
# 0.9530612244897959

# %%
def get_model(params):
  return Sequential([
    Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=input_shape),
    Conv2D(filters=32, kernel_size=(3,3), activation='relu',padding='same'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_one']),

    Conv2D(filters=64, kernel_size=(3,3), activation='relu',padding='same'),
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_two']),

    Conv2D(filters=128, kernel_size=(3,3), activation='relu',padding='same'),
    Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_three']),
    Flatten(),

    Dense(1024, activation='relu'),
    Dropout(params['dropout_dense_block_one']),

    Dense(1024, activation='relu'),
    Dropout(params['dropout_dense_block_two']),

    Dense(num_classes, activation='softmax'),
  ])

# %%
def func_obj(params):
  model = get_model(params)
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
  
  model.fit(
      X_train,
      y_train,
      batch_size = int(params.get('batch_size', 128)),
      epochs = 5,
      verbose = 0
    )

  accuracy = model.evaluate(X_test, y_test)[0]
  print(params, 'accuracy={}'.format(accuracy))

  return {'loss': -accuracy, 'status' : STATUS_OK, 'model':model}

# %%
space = {
    'batch_size': hp.quniform('batch_size', 10, 200, 10),
    'dropout_cnn_block_one': hp.uniform('dropout_cnn_block_one', 0.3, 0.5),
#
# 137/138 [============================>.]
#  - ETA: 0s - loss: 0.1917 - accuracy: 0.9389
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1991 - accuracy: 0.9345
#
# {'batch_size': 60.0, 'dropout_cnn_block_one': 0.4294935495852666, 'dropout_cnn_block_three': 0.46072652959614246, 'dropout_cnn_block_two': 0.3572732646359258, 'dropout_dense_block_one': 0.4773513062172165, 'dropout_dense_block_two': 0.6016162025265317}
# accuracy=0.19912421703338623
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.9466 - accuracy: 0.3125
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.7139 - accuracy: 0.7522
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.8337 - accuracy: 0.7396
#
#  34/138 [======>.......................]
#  - ETA: 0s - loss: 0.6829 - accuracy: 0.7932
#
#  45/138 [========>.....................]
#  - ETA: 0s - loss: 0.7265 - accuracy: 0.7646
#
#  57/138 [===========>..................]
#  - ETA: 0s - loss: 0.8092 - accuracy: 0.7462
#
#  69/138 [==============>...............]
#  - ETA: 0s - loss: 0.8098 - accuracy: 0.7373
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.7179 - accuracy: 0.7704
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.6876 - accuracy: 0.7717
#
# 102/138 [=====================>........]
#  - ETA: 0s - loss: 0.7129 - accuracy: 0.7613
#
# 112/138 [=======================>......]
#  - ETA: 0s - loss: 0.7436 - accuracy: 0.7559
#
# 121/138 [=========================>....]
#  - ETA: 0s - loss: 0.7094 - accuracy: 0.7694
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 0.6964 - accuracy: 0.7732
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.6830 - accuracy: 0.7812
#
# {'batch_size': 10.0, 'dropout_cnn_block_one': 0.4218368768628456, 'dropout_cnn_block_three': 0.4647371501553036, 'dropout_cnn_block_two': 0.3579023492994927, 'dropout_dense_block_one': 0.49079083392985867, 'dropout_dense_block_two': 0.6085683040382897}
# accuracy=0.6830011010169983
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.3272 - accuracy: 0.8750
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 0.2028 - accuracy: 0.9432
#
#  22/138 [===>..........................]
#  - ETA: 0s - loss: 0.5653 - accuracy: 0.8949
#
#  34/138 [======>.......................]
#  - ETA: 0s - loss: 0.6480 - accuracy: 0.8612
#
#  46/138 [=========>....................]
#  - ETA: 0s - loss: 0.7554 - accuracy: 0.7948
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 0.6731 - accuracy: 0.8114
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 0.6023 - accuracy: 0.8319
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.5219 - accuracy: 0.8547
#
#  89/138 [==================>...........]
#  - ETA: 0s - loss: 0.4568 - accuracy: 0.8732
#
# 102/138 [=====================>........]
#  - ETA: 0s - loss: 0.4282 - accuracy: 0.8845
#
# 114/138 [=======================>......]
#  - ETA: 0s - loss: 0.4219 - accuracy: 0.8835
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.3840 - accuracy: 0.8936
#
# 136/138 [============================>.]
#  - ETA: 0s - loss: 0.3693 - accuracy: 0.8936
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.3642 - accuracy: 0.8950
#
# {'batch_size': 70.0, 'dropout_cnn_block_one': 0.44450378998263207, 'dropout_cnn_block_three': 0.4669921038532648, 'dropout_cnn_block_two': 0.3621314155936869, 'dropout_dense_block_one': 0.4433718200469073, 'dropout_dense_block_two': 0.5547294427027754}
# accuracy=0.36420413851737976
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.4039 - accuracy: 0.2500
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.8990 - accuracy: 0.6707
#
#  25/138 [====>.........................]
#  - ETA: 0s - loss: 1.2468 - accuracy: 0.6125
#
#  37/138 [=======>......................]
#  - ETA: 0s - loss: 1.0369 - accuracy: 0.6748
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 1.1480 - accuracy: 0.6426
#
#  59/138 [===========>..................]
#  - ETA: 0s - loss: 1.0640 - accuracy: 0.6711
#
#  71/138 [==============>...............]
#  - ETA: 0s - loss: 0.9925 - accuracy: 0.7011
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.9344 - accuracy: 0.7184
#
#  89/138 [==================>...........]
#  - ETA: 0s - loss: 0.8747 - accuracy: 0.7335
#
#  99/138 [====================>.........]
#  - ETA: 0s - loss: 0.8391 - accuracy: 0.7478
#
# 111/138 [=======================>......]
#  - ETA: 0s - loss: 0.8764 - accuracy: 0.7373
#
# 122/138 [=========================>....]
#  - ETA: 0s - loss: 0.8311 - accuracy: 0.7485
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 0.8222 - accuracy: 0.7469
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.7981 - accuracy: 0.7556
#
# {'batch_size': 10.0, 'dropout_cnn_block_one': 0.3071935440153545, 'dropout_cnn_block_three': 0.4403761206386628, 'dropout_cnn_block_two': 0.36761945202411844, 'dropout_dense_block_one': 0.3654203148469747, 'dropout_dense_block_two': 0.6117257624648503}
# accuracy=0.7981301546096802
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.7387 - accuracy: 0.7188
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.2640 - accuracy: 0.9279
#
#  23/138 [====>.........................]
#  - ETA: 0s - loss: 0.7621 - accuracy: 0.8736
#
#  34/138 [======>.......................]
#  - ETA: 0s - loss: 0.5344 - accuracy: 0.9108
#
#  45/138 [========>.....................]
#  - ETA: 0s - loss: 0.4906 - accuracy: 0.9042
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 0.4772 - accuracy: 0.8929
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 0.5152 - accuracy: 0.8859
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.4477 - accuracy: 0.9014
#
#  87/138 [=================>............]
#  - ETA: 0s - loss: 0.4225 - accuracy: 0.9030
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.3929 - accuracy: 0.9091
#
# 110/138 [======================>.......]
#  - ETA: 0s - loss: 0.4116 - accuracy: 0.9028
#
# 123/138 [=========================>....]
#  - ETA: 0s - loss: 0.3688 - accuracy: 0.9131
#
# 135/138 [============================>.]
#  - ETA: 0s - loss: 0.3523 - accuracy: 0.9144
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.3455 - accuracy: 0.9159
#
# {'batch_size': 90.0, 'dropout_cnn_block_one': 0.46440197139849904, 'dropout_cnn_block_three': 0.43988191799762844, 'dropout_cnn_block_two': 0.3440504899693792, 'dropout_dense_block_one': 0.4500309774169352, 'dropout_dense_block_two': 0.5514513118810159}
# accuracy=0.3455254137516022
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.4242 - accuracy: 0.8125
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 0.2262 - accuracy: 0.9401
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.5616 - accuracy: 0.8763
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 0.4198 - accuracy: 0.8984
#
#  47/138 [=========>....................]
#  - ETA: 0s - loss: 0.4924 - accuracy: 0.8537
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 0.4979 - accuracy: 0.8454
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 0.4677 - accuracy: 0.8520
#
#  80/138 [================>.............]
#  - ETA: 0s - loss: 0.4035 - accuracy: 0.8723
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.3620 - accuracy: 0.8862
#
# 103/138 [=====================>........]
#  - ETA: 0s - loss: 0.3853 - accuracy: 0.8799
#
# 115/138 [========================>.....]
#  - ETA: 0s - loss: 0.3702 - accuracy: 0.8870
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.3428 - accuracy: 0.8956
#
# 137/138 [============================>.]
#  - ETA: 0s - loss: 0.3277 - accuracy: 0.8967
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.3255 - accuracy: 0.8973
#
# {'batch_size': 50.0, 'dropout_cnn_block_one': 0.4385681804211652, 'dropout_cnn_block_three': 0.47665531246204235, 'dropout_cnn_block_two': 0.49187545883014583, 'dropout_dense_block_one': 0.33306068606911343, 'dropout_dense_block_two': 0.6390149343959947}
# accuracy=0.3254930377006531
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.4746 - accuracy: 0.8750
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.1127 - accuracy: 0.9732
#
#  25/138 [====>.........................]
#  - ETA: 0s - loss: 0.2547 - accuracy: 0.9250
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 0.1843 - accuracy: 0.9470
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 0.2026 - accuracy: 0.9395
#
#  60/138 [============>.................]
#  - ETA: 0s - loss: 0.1710 - accuracy: 0.9500
#
#  71/138 [==============>...............]
#  - ETA: 0s - loss: 0.1550 - accuracy: 0.9551
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.1379 - accuracy: 0.9603
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.1301 - accuracy: 0.9623
#
# 103/138 [=====================>........]
#  - ETA: 0s - loss: 0.1367 - accuracy: 0.9612
#
# 115/138 [========================>.....]
#  - ETA: 0s - loss: 0.1326 - accuracy: 0.9617
#
# 124/138 [=========================>....]
#  - ETA: 0s - loss: 0.1318 - accuracy: 0.9624
#
# 136/138 [============================>.]
#  - ETA: 0s - loss: 0.1435 - accuracy: 0.9557
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1439 - accuracy: 0.9556
#
# {'batch_size': 80.0, 'dropout_cnn_block_one': 0.4057139493299781, 'dropout_cnn_block_three': 0.4248708363078081, 'dropout_cnn_block_two': 0.34477285793783763, 'dropout_dense_block_one': 0.37180952566349473, 'dropout_dense_block_two': 0.5858465468224169}
# accuracy=0.143891841173172
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.4898 - accuracy: 0.0625
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.7376 - accuracy: 0.8058
#
#  27/138 [====>.........................]
#  - ETA: 0s - loss: 1.1898 - accuracy: 0.7118
#
#  37/138 [=======>......................]
#  - ETA: 0s - loss: 0.9922 - accuracy: 0.7432
#
#  49/138 [=========>....................]
#  - ETA: 0s - loss: 1.0177 - accuracy: 0.7066
#
#  60/138 [============>.................]
#  - ETA: 0s - loss: 0.9342 - accuracy: 0.7276
#
#  71/138 [==============>...............]
#  - ETA: 0s - loss: 0.8562 - accuracy: 0.7469
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 0.7774 - accuracy: 0.7636
#
#  94/138 [===================>..........]
#  - ETA: 0s - loss: 0.7070 - accuracy: 0.7793
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.7471 - accuracy: 0.7647
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.6944 - accuracy: 0.7823
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 0.6765 - accuracy: 0.7888
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.6546 - accuracy: 0.7991
#
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.33666185611450095, 'dropout_cnn_block_three': 0.49834718232874264, 'dropout_cnn_block_two': 0.3730260508442718, 'dropout_dense_block_one': 0.513391996246697, 'dropout_dense_block_two': 0.5370834067254184}
# accuracy=0.6546154618263245
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.5321 - accuracy: 0.8750
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.3519 - accuracy: 0.9085
#
#  26/138 [====>.........................]
#  - ETA: 0s - loss: 1.0611 - accuracy: 0.7788
#
#  38/138 [=======>......................]
#  - ETA: 0s - loss: 0.7725 - accuracy: 0.8322
#
#  48/138 [=========>....................]
#  - ETA: 0s - loss: 0.8194 - accuracy: 0.8099
#
#  59/138 [===========>..................]
#  - ETA: 0s - loss: 0.6981 - accuracy: 0.8390
#
#  70/138 [==============>...............]
#  - ETA: 0s - loss: 0.6315 - accuracy: 0.8509
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.5928 - accuracy: 0.8553
#
#  92/138 [===================>..........]
#  - ETA: 0s - loss: 0.5448 - accuracy: 0.8638
#
# 104/138 [=====================>........]
#  - ETA: 0s - loss: 0.5455 - accuracy: 0.8552
#
# 115/138 [========================>.....]
#  - ETA: 0s - loss: 0.5416 - accuracy: 0.8571
#
# 125/138 [==========================>...]
#  - ETA: 0s - loss: 0.5026 - accuracy: 0.8670
#
# 134/138 [============================>.]
#  - ETA: 0s - loss: 0.4919 - accuracy: 0.8652
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.4973 - accuracy: 0.8642
#
# {'batch_size': 20.0, 'dropout_cnn_block_one': 0.3409992675499713, 'dropout_cnn_block_three': 0.45173286477105895, 'dropout_cnn_block_two': 0.4040068584869444, 'dropout_dense_block_one': 0.4520505694193302, 'dropout_dense_block_two': 0.6487241002763872}
# accuracy=0.4972812831401825
# 100%|██████████| 30/30 [14:32<00:00, 29.10s/it, best loss: -0.9747695922851562]
